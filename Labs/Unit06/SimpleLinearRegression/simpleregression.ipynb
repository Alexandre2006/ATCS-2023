# %% [markdown]
# # Simple Linear Regression
# An example of how to create a Simple Linear Regression model using sklearn and data about crickets.

# %% [markdown]
# ## 1. Import libraries and load data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("data/chirping.csv")

# %% [markdown]
# ## 2. Determine if we can use Simple Linear Regression
# * Data must be quantitative
# * Data must have a linear relationship

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Chirps  11 non-null     float64
#  1   Temp    11 non-null     float64
# dtypes: float64(2)
# memory usage: 308.0 bytes

# %%
plt.title("Temp vs Chirps")
sns.scatterplot(x="Temp", y="Chirps", data=df)
# Out:
# <Axes: title={'center': 'Temp vs Chirps'}, xlabel='Temp', ylabel='Chirps'>

# %% [markdown]
# ## 3. Creating the Model

# %%
# Extract our data
X_train = df[["Temp"]]
y_train = df["Chirps"]

# Create the model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 4. Use the model for a prediction

# %%
model.predict([[i*2] for i in range(16, 50)])
# Out:
# /Users/thinkalex/Desktop/ATCS/Labs/Unit06/SimpleLinearRegression/.venv/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-11.31003902,  -8.93887873,  -6.56771843,  -4.19655814,
#         -1.82539784,   0.54576245,   2.91692275,   5.28808304,
#          7.65924334,  10.03040363,  12.40156393,  14.77272422,
#         17.14388452,  19.51504481,  21.88620511,  24.2573654 ,
#         26.6285257 ,  28.99968599,  31.37084629,  33.74200658,
#         36.11316688,  38.48432718,  40.85548747,  43.22664777,
#         45.59780806,  47.96896836,  50.34012865,  52.71128895,
#         55.08244924,  57.45360954,  59.82476983,  62.19593013,
#         64.56709042,  66.93825072])

# %% [markdown]
# ## 5. Plot the Line of Best Fit

# %%
plt.title("Temp vs Chirps")
sns.scatterplot(x="Temp", y="Chirps", data=df)

plt.plot(X_train, model.predict(X_train), color="red")
